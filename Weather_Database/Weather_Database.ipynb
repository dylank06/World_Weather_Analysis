# %%
# Import the dependencies.
import pandas as pd

import numpy as np
# Import the random module.
import random
# Import timeit.
import timeit
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# 1. Create a new set of 2,000 random latitudes and longitudes.
np.random.seed(0)
# random.uniform retuns a floating-point decimal number between the interval. Size 2000.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# The zip object packs each pair of lats and lngs having the same index in their respective array
# into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 2. Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinates in coordinates:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# 3. Perform an API call with the OpenWeatherMap.

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02c82f8c39c3b24b1ca3c0197a4929f2

# %%
#%%time
# 4. Retrieve the following information from the API call:
    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 1 | vendas novas
# Processing Record 3 of Set 1 | arlit
# Processing Record 4 of Set 1 | santa cruz
# Processing Record 5 of Set 1 | montepuez
# Processing Record 6 of Set 1 | cockburn town
# Processing Record 7 of Set 1 | lubumbashi
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | caravelas
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | burica
# City not found. Skipping...
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | kargasok
# Processing Record 19 of Set 1 | skibbereen
# Processing Record 20 of Set 1 | belaya gora
# Processing Record 21 of Set 1 | barrhead
# Processing Record 22 of Set 1 | jacareacanga
# Processing Record 23 of Set 1 | dovbysh
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | codrington
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | limbang
# Processing Record 28 of Set 1 | janauba
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | suicheng
# Processing Record 35 of Set 1 | loikaw
# Processing Record 36 of Set 1 | bilma
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | inhambane
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | nederland
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | pascagoula
# Processing Record 1 of Set 2 | soyo
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | jalu
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | yerbogachen
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | gamba
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | karpathos
# Processing Record 16 of Set 2 | trincomalee
# Processing Record 17 of Set 2 | bhatkal
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | brenham
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | bara
# Processing Record 24 of Set 2 | stornoway
# Processing Record 25 of Set 2 | hillsboro
# Processing Record 26 of Set 2 | pitsunda
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | waitati
# Processing Record 29 of Set 2 | kavaratti
# Processing Record 30 of Set 2 | palasa
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | siloam springs
# Processing Record 34 of Set 2 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 35 of Set 2 | opuwo
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | palauig
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | at-bashi
# Processing Record 41 of Set 2 | itarema
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | los llanos de aridane
# Processing Record 44 of Set 2 | cairns
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | whitianga
# Processing Record 47 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | ulladulla
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | kattivakkam
# Processing Record 4 of Set 3 | valentin gomez farias
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | rodrigues alves
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | walvis bay
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | lebyazhye
# Processing Record 11 of Set 3 | licata
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | dandong
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | komsomolskiy
# Processing Record 16 of Set 3 | naze
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | dukhovshchina
# Processing Record 19 of Set 3 | kralendijk
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | mirina
# City not found. Skipping...
# Processing Record 23 of Set 3 | tura
# Processing Record 24 of Set 3 | kysyl-syr
# Processing Record 25 of Set 3 | vila velha
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | kapaa
# Processing Record 32 of Set 3 | kutum
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | riyadh
# Processing Record 36 of Set 3 | meiganga
# Processing Record 37 of Set 3 | campobasso
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | poum
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | zhanaozen
# Processing Record 42 of Set 3 | port-gentil
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | san lazaro
# Processing Record 46 of Set 3 | nalut
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | namatanai
# Processing Record 49 of Set 3 | kjollefjord
# Processing Record 50 of Set 3 | pisco
# Processing Record 1 of Set 4 | barra patuca
# Processing Record 2 of Set 4 | rudnogorsk
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | cherskiy
# Processing Record 6 of Set 4 | nemuro
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | rio gallegos
# Processing Record 9 of Set 4 | boa vista
# Processing Record 10 of Set 4 | morrope
# Processing Record 11 of Set 4 | ourossogui
# Processing Record 12 of Set 4 | zyryanka
# Processing Record 13 of Set 4 | clarksburg
# Processing Record 14 of Set 4 | capinopolis
# Processing Record 15 of Set 4 | prachuap khiri khan
# Processing Record 16 of Set 4 | kaeo
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | marfino
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | coahuayana
# Processing Record 22 of Set 4 | pandan
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | kungurtug
# Processing Record 26 of Set 4 | salinas
# Processing Record 27 of Set 4 | narsaq
# Processing Record 28 of Set 4 | rovaniemi
# Processing Record 29 of Set 4 | broken hill
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | mehamn
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | haicheng
# Processing Record 34 of Set 4 | srednekolymsk
# Processing Record 35 of Set 4 | oktyabrskoye
# Processing Record 36 of Set 4 | beihai
# Processing Record 37 of Set 4 | vallenar
# Processing Record 38 of Set 4 | angoram
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | jacqueville
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | pangnirtung
# Processing Record 44 of Set 4 | krasnyy chikoy
# Processing Record 45 of Set 4 | kalach-na-donu
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | natitingou
# Processing Record 48 of Set 4 | vestmanna
# Processing Record 49 of Set 4 | ottumwa
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | pitimbu
# Processing Record 3 of Set 5 | wilmington
# Processing Record 4 of Set 5 | sidi ali
# Processing Record 5 of Set 5 | victor harbor
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | lac du bonnet
# Processing Record 8 of Set 5 | flagstaff
# Processing Record 9 of Set 5 | zbarazh
# Processing Record 10 of Set 5 | sinnamary
# Processing Record 11 of Set 5 | mitsamiouli
# Processing Record 12 of Set 5 | yerofey pavlovich
# Processing Record 13 of Set 5 | sao filipe
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | batemans bay
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | los algarrobos
# Processing Record 21 of Set 5 | itaueira
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | manono
# Processing Record 24 of Set 5 | cedartown
# Processing Record 25 of Set 5 | torbay
# Processing Record 26 of Set 5 | shingu
# Processing Record 27 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 5 | mayumba
# Processing Record 29 of Set 5 | kamphaeng phet
# Processing Record 30 of Set 5 | mayo
# Processing Record 31 of Set 5 | pochutla
# Processing Record 32 of Set 5 | terrace
# Processing Record 33 of Set 5 | mantua
# Processing Record 34 of Set 5 | denpasar
# Processing Record 35 of Set 5 | iqaluit
# Processing Record 36 of Set 5 | mount isa
# Processing Record 37 of Set 5 | havoysund
# Processing Record 38 of Set 5 | ostrovnoy
# Processing Record 39 of Set 5 | lata
# Processing Record 40 of Set 5 | bucerias
# Processing Record 41 of Set 5 | bengkulu
# Processing Record 42 of Set 5 | avarua
# Processing Record 43 of Set 5 | guiratinga
# Processing Record 44 of Set 5 | sibolga
# Processing Record 45 of Set 5 | tuatapere
# Processing Record 46 of Set 5 | tezu
# Processing Record 47 of Set 5 | amapa
# Processing Record 48 of Set 5 | becerril
# Processing Record 49 of Set 5 | cap malheureux
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | ullapool
# Processing Record 2 of Set 6 | carnarvon
# Processing Record 3 of Set 6 | severnoye
# Processing Record 4 of Set 6 | berlevag
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | margate
# Processing Record 7 of Set 6 | port lincoln
# Processing Record 8 of Set 6 | iwade
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | chiredzi
# Processing Record 11 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 6 | tilichiki
# Processing Record 13 of Set 6 | sandnessjoen
# Processing Record 14 of Set 6 | gofitskoye
# Processing Record 15 of Set 6 | asheville
# Processing Record 16 of Set 6 | lucapa
# Processing Record 17 of Set 6 | banjar
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | deputatskiy
# Processing Record 20 of Set 6 | bedele
# Processing Record 21 of Set 6 | coracao de jesus
# Processing Record 22 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 6 | banda aceh
# Processing Record 24 of Set 6 | kirovskiy
# Processing Record 25 of Set 6 | noumea
# Processing Record 26 of Set 6 | rapid valley
# Processing Record 27 of Set 6 | hondo
# Processing Record 28 of Set 6 | marsala
# Processing Record 29 of Set 6 | calabozo
# Processing Record 30 of Set 6 | seoul
# Processing Record 31 of Set 6 | laranjal paulista
# Processing Record 32 of Set 6 | ibra
# Processing Record 33 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 6 | camacha
# Processing Record 35 of Set 6 | huzhou
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | cabo san lucas
# Processing Record 38 of Set 6 | nagahama
# Processing Record 39 of Set 6 | bridlington
# Processing Record 40 of Set 6 | nhulunbuy
# Processing Record 41 of Set 6 | sarangani
# Processing Record 42 of Set 6 | saint-pierre
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | atar
# Processing Record 45 of Set 6 | talaja
# Processing Record 46 of Set 6 | takoradi
# Processing Record 47 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 6 | miracema do tocantins
# Processing Record 50 of Set 6 | dayong
# Processing Record 1 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 7 | tasiilaq
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | sorland
# Processing Record 5 of Set 7 | taltal
# Processing Record 6 of Set 7 | guangyuan
# Processing Record 7 of Set 7 | anloga
# Processing Record 8 of Set 7 | santa cruz de tenerife
# Processing Record 9 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 7 | bayburt
# Processing Record 11 of Set 7 | taksimo
# Processing Record 12 of Set 7 | baruun-urt
# Processing Record 13 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | labuhan
# Processing Record 16 of Set 7 | goderich
# Processing Record 17 of Set 7 | emba
# Processing Record 18 of Set 7 | mucuri
# Processing Record 19 of Set 7 | beitbridge
# Processing Record 20 of Set 7 | zlitan
# Processing Record 21 of Set 7 | turukhansk
# Processing Record 22 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 7 | salalah
# Processing Record 24 of Set 7 | anadyr
# Processing Record 25 of Set 7 | carauari
# Processing Record 26 of Set 7 | buin
# Processing Record 27 of Set 7 | skelleftea
# Processing Record 28 of Set 7 | belmonte
# Processing Record 29 of Set 7 | zarand
# Processing Record 30 of Set 7 | florianopolis
# Processing Record 31 of Set 7 | jinchang
# Processing Record 32 of Set 7 | nouadhibou
# Processing Record 33 of Set 7 | yantal
# Processing Record 34 of Set 7 | shaowu
# Processing Record 35 of Set 7 | acarau
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | ballina
# Processing Record 39 of Set 7 | oneonta
# Processing Record 40 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 41 of Set 7 | los alamos
# Processing Record 42 of Set 7 | robertsport
# Processing Record 43 of Set 7 | tebingtinggi
# Processing Record 44 of Set 7 | kenai
# Processing Record 45 of Set 7 | muyezerskiy
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | prince rupert
# Processing Record 48 of Set 7 | mzimba
# Processing Record 49 of Set 7 | kibre mengist
# Processing Record 50 of Set 7 | ivybridge
# Processing Record 1 of Set 8 | aviles
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 4 of Set 8 | moscow
# Processing Record 5 of Set 8 | garissa
# Processing Record 6 of Set 8 | kieta
# Processing Record 7 of Set 8 | asfi
# Processing Record 8 of Set 8 | necochea
# Processing Record 9 of Set 8 | puerto vallarta
# Processing Record 10 of Set 8 | cockeysville
# Processing Record 11 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 8 | san rafael
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | dunda
# Processing Record 15 of Set 8 | luanda
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | henties bay
# Processing Record 18 of Set 8 | swan river
# Processing Record 19 of Set 8 | barcelos
# Processing Record 20 of Set 8 | ostersund
# Processing Record 21 of Set 8 | sao miguel do araguaia
# Processing Record 22 of Set 8 | solnechnyy
# Processing Record 23 of Set 8 | port keats
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | alugan
# Processing Record 26 of Set 8 | yar-sale
# Processing Record 27 of Set 8 | neiafu
# Processing Record 28 of Set 8 | key biscayne
# Processing Record 29 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 8 | sakaiminato
# Processing Record 31 of Set 8 | vao
# Processing Record 32 of Set 8 | saint-felicien
# Processing Record 33 of Set 8 | tateyama
# Processing Record 34 of Set 8 | otorohanga
# Processing Record 35 of Set 8 | prado
# Processing Record 36 of Set 8 | olovo
# Processing Record 37 of Set 8 | amuntai
# Processing Record 38 of Set 8 | olafsvik
# Processing Record 39 of Set 8 | bathsheba
# Processing Record 40 of Set 8 | gazanjyk
# Processing Record 41 of Set 8 | guamuchil
# Processing Record 42 of Set 8 | arawa
# Processing Record 43 of Set 8 | leningradskiy
# Processing Record 44 of Set 8 | coihueco
# Processing Record 45 of Set 8 | placerville
# Processing Record 46 of Set 8 | serebryanyy bor
# Processing Record 47 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 8 | trairi
# Processing Record 50 of Set 8 | fortuna
# Processing Record 1 of Set 9 | buala
# Processing Record 2 of Set 9 | hervey bay
# Processing Record 3 of Set 9 | neuquen
# Processing Record 4 of Set 9 | avera
# Processing Record 5 of Set 9 | santa fe
# Processing Record 6 of Set 9 | paso de los toros
# Processing Record 7 of Set 9 | kroya
# Processing Record 8 of Set 9 | goycay
# City not found. Skipping...
# Processing Record 9 of Set 9 | khovu-aksy
# Processing Record 10 of Set 9 | likasi
# Processing Record 11 of Set 9 | macas
# Processing Record 12 of Set 9 | dharmapuri
# Processing Record 13 of Set 9 | mecca
# Processing Record 14 of Set 9 | thinadhoo
# Processing Record 15 of Set 9 | pontes e lacerda
# Processing Record 16 of Set 9 | bilibino
# Processing Record 17 of Set 9 | aklavik
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | inuvik
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | beloha
# Processing Record 22 of Set 9 | pasco
# Processing Record 23 of Set 9 | malakal
# Processing Record 24 of Set 9 | yerakarou
# City not found. Skipping...
# Processing Record 25 of Set 9 | port alberni
# Processing Record 26 of Set 9 | ambon
# Processing Record 27 of Set 9 | ust-kishert
# Processing Record 28 of Set 9 | arbroath
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | coquimbo
# Processing Record 31 of Set 9 | nizhniye sergi
# Processing Record 32 of Set 9 | tual
# Processing Record 33 of Set 9 | lethem
# Processing Record 34 of Set 9 | khandyga
# Processing Record 35 of Set 9 | maneromango
# Processing Record 36 of Set 9 | zhigansk
# Processing Record 37 of Set 9 | marystown
# Processing Record 38 of Set 9 | manta
# Processing Record 39 of Set 9 | bensonville
# Processing Record 40 of Set 9 | raudeberg
# Processing Record 41 of Set 9 | vranov
# Processing Record 42 of Set 9 | biak
# Processing Record 43 of Set 9 | canandaigua
# Processing Record 44 of Set 9 | nola
# Processing Record 45 of Set 9 | darya khan
# Processing Record 46 of Set 9 | tarakan
# Processing Record 47 of Set 9 | ginda
# Processing Record 48 of Set 9 | windsor
# Processing Record 49 of Set 9 | barmer
# Processing Record 50 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 1 of Set 10 | axim
# Processing Record 2 of Set 10 | mahibadhoo
# Processing Record 3 of Set 10 | rosario
# Processing Record 4 of Set 10 | tainan
# Processing Record 5 of Set 10 | struthers
# Processing Record 6 of Set 10 | lumeje
# Processing Record 7 of Set 10 | tiznit
# Processing Record 8 of Set 10 | vestmannaeyjar
# Processing Record 9 of Set 10 | ancud
# Processing Record 10 of Set 10 | hambantota
# Processing Record 11 of Set 10 | kodinsk
# Processing Record 12 of Set 10 | sheregesh
# Processing Record 13 of Set 10 | melaka
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | shaunavon
# Processing Record 16 of Set 10 | sisimiut
# Processing Record 17 of Set 10 | dawlatabad
# Processing Record 18 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | sudbury
# Processing Record 20 of Set 10 | beringovskiy
# Processing Record 21 of Set 10 | kinsale
# Processing Record 22 of Set 10 | buta
# Processing Record 23 of Set 10 | alta floresta
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | teya
# Processing Record 26 of Set 10 | nouakchott
# Processing Record 27 of Set 10 | northam
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | goshogawara
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | safford
# Processing Record 32 of Set 10 | viedma
# Processing Record 33 of Set 10 | gorontalo
# Processing Record 34 of Set 10 | birecik
# Processing Record 35 of Set 10 | asyut
# Processing Record 36 of Set 10 | sioux lookout
# Processing Record 37 of Set 10 | znamenskoye
# Processing Record 38 of Set 10 | shetpe
# Processing Record 39 of Set 10 | dumabato
# Processing Record 40 of Set 10 | daru
# Processing Record 41 of Set 10 | uyuni
# Processing Record 42 of Set 10 | matongo
# Processing Record 43 of Set 10 | ridgecrest
# Processing Record 44 of Set 10 | port arthur
# Processing Record 45 of Set 10 | nkowakowa
# Processing Record 46 of Set 10 | paamiut
# Processing Record 47 of Set 10 | ranong
# Processing Record 48 of Set 10 | quelimane
# Processing Record 49 of Set 10 | flinders
# Processing Record 50 of Set 10 | izhma
# Processing Record 1 of Set 11 | san jeronimo
# Processing Record 2 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 3 of Set 11 | achit
# Processing Record 4 of Set 11 | owando
# Processing Record 5 of Set 11 | erzin
# Processing Record 6 of Set 11 | masaya
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | mutoko
# Processing Record 9 of Set 11 | goryachegorsk
# Processing Record 10 of Set 11 | kati
# Processing Record 11 of Set 11 | sug-aksy
# City not found. Skipping...
# Processing Record 12 of Set 11 | isangel
# Processing Record 13 of Set 11 | puquio
# Processing Record 14 of Set 11 | sept-iles
# Processing Record 15 of Set 11 | leh
# Processing Record 16 of Set 11 | kherson
# Processing Record 17 of Set 11 | dinard
# Processing Record 18 of Set 11 | sorong
# Processing Record 19 of Set 11 | saratov
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | wicklow
# Processing Record 22 of Set 11 | zalesovo
# Processing Record 23 of Set 11 | kalmunai
# Processing Record 24 of Set 11 | de aar
# Processing Record 25 of Set 11 | karratha
# Processing Record 26 of Set 11 | marsh harbour
# Processing Record 27 of Set 11 | sobolevo
# Processing Record 28 of Set 11 | hit
# Processing Record 29 of Set 11 | keti bandar
# Processing Record 30 of Set 11 | gonc
# Processing Record 31 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 32 of Set 11 | vila
# Processing Record 33 of Set 11 | adelaide
# Processing Record 34 of Set 11 | shakawe
# Processing Record 35 of Set 11 | tallahassee
# Processing Record 36 of Set 11 | tsiroanomandidy
# Processing Record 37 of Set 11 | tampakan
# Processing Record 38 of Set 11 | wanaka
# Processing Record 39 of Set 11 | virginia beach
# Processing Record 40 of Set 11 | nador
# Processing Record 41 of Set 11 | antofagasta
# Processing Record 42 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 11 | riviere-du-loup
# Processing Record 45 of Set 11 | hamilton
# Processing Record 46 of Set 11 | tottori
# Processing Record 47 of Set 11 | devils lake
# Processing Record 48 of Set 11 | knysna
# Processing Record 49 of Set 11 | batticaloa
# Processing Record 50 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 12 | te anau
# Processing Record 2 of Set 12 | taranagar
# Processing Record 3 of Set 12 | boshnyakovo
# Processing Record 4 of Set 12 | sault sainte marie
# Processing Record 5 of Set 12 | gemena
# Processing Record 6 of Set 12 | syracuse
# Processing Record 7 of Set 12 | udachnyy
# Processing Record 8 of Set 12 | kulhudhuffushi
# Processing Record 9 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 10 of Set 12 | kantunilkin
# Processing Record 11 of Set 12 | bulgan
# Processing Record 12 of Set 12 | luderitz
# Processing Record 13 of Set 12 | naranjito
# Processing Record 14 of Set 12 | lavrentiya
# Processing Record 15 of Set 12 | cravo norte
# Processing Record 16 of Set 12 | mount gambier
# Processing Record 17 of Set 12 | wanxian
# Processing Record 18 of Set 12 | thakurgaon
# Processing Record 19 of Set 12 | havelock
# Processing Record 20 of Set 12 | sumatac
# Processing Record 21 of Set 12 | rio verde de mato grosso
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | matara
# Processing Record 24 of Set 12 | zhangye
# Processing Record 25 of Set 12 | itacoatiara
# Processing Record 26 of Set 12 | hurricane
# Processing Record 27 of Set 12 | vilcun
# Processing Record 28 of Set 12 | great bend
# Processing Record 29 of Set 12 | road town
# Processing Record 30 of Set 12 | saravena
# Processing Record 31 of Set 12 | contamana
# Processing Record 32 of Set 12 | ola
# Processing Record 33 of Set 12 | erdenet
# Processing Record 34 of Set 12 | along
# Processing Record 35 of Set 12 | oranjemund
# Processing Record 36 of Set 12 | teguise
# Processing Record 37 of Set 12 | brownsville
# Processing Record 38 of Set 12 | samarai
# Processing Record 39 of Set 12 | bintulu
# Processing Record 40 of Set 12 | arrifes
# Processing Record 41 of Set 12 | bartica
# Processing Record 42 of Set 12 | pinheiral
# Processing Record 43 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 44 of Set 12 | ambilobe
# Processing Record 45 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 46 of Set 12 | hasaki
# Processing Record 47 of Set 12 | goundam
# Processing Record 48 of Set 12 | bowen
# Processing Record 49 of Set 12 | parksville
# Processing Record 50 of Set 12 | genhe
# Processing Record 1 of Set 13 | sao joao da barra
# Processing Record 2 of Set 13 | melur
# Processing Record 3 of Set 13 | shu
# Processing Record 4 of Set 13 | hammerfest
# Processing Record 5 of Set 13 | sangueya
# Processing Record 6 of Set 13 | sao jose da coroa grande
# Processing Record 7 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 13 | vila franca do campo
# Processing Record 9 of Set 13 | dongsheng
# Processing Record 10 of Set 13 | fairbanks
# Processing Record 11 of Set 13 | asopos
# Processing Record 12 of Set 13 | catamarca
# Processing Record 13 of Set 13 | havre-saint-pierre
# Processing Record 14 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 13 | ampanihy
# Processing Record 16 of Set 13 | tanjong sepat
# City not found. Skipping...
# Processing Record 17 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 13 | mudon
# Processing Record 19 of Set 13 | mastic beach
# Processing Record 20 of Set 13 | san juan
# Processing Record 21 of Set 13 | sukhumi
# Processing Record 22 of Set 13 | lompoc
# Processing Record 23 of Set 13 | knyaze-volkonskoye
# Processing Record 24 of Set 13 | fort nelson
# Processing Record 25 of Set 13 | chaiyaphum
# Processing Record 26 of Set 13 | kaspiysk
# Processing Record 27 of Set 13 | juneau
# Processing Record 28 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 13 | luganville
# Processing Record 30 of Set 13 | xichang
# Processing Record 31 of Set 13 | minab
# Processing Record 32 of Set 13 | taebla
# Processing Record 33 of Set 13 | kishtwar
# Processing Record 34 of Set 13 | tautira
# Processing Record 35 of Set 13 | tiradentes
# Processing Record 36 of Set 13 | la concordia
# Processing Record 37 of Set 13 | muisne
# Processing Record 38 of Set 13 | mujiayingzi
# Processing Record 39 of Set 13 | shubarkuduk
# Processing Record 40 of Set 13 | arona
# Processing Record 41 of Set 13 | sergeyevka
# Processing Record 42 of Set 13 | saint-georges
# Processing Record 43 of Set 13 | maumere
# Processing Record 44 of Set 13 | prince george
# Processing Record 45 of Set 13 | tupik
# Processing Record 46 of Set 13 | wageningen
# Processing Record 47 of Set 13 | marrakesh
# Processing Record 48 of Set 13 | maiduguri
# Processing Record 49 of Set 13 | kerema
# Processing Record 50 of Set 13 | les cayes
# Processing Record 1 of Set 14 | tambopata
# Processing Record 2 of Set 14 | odweyne
# Processing Record 3 of Set 14 | half moon bay
# Processing Record 4 of Set 14 | guarapari
# Processing Record 5 of Set 14 | chara
# Processing Record 6 of Set 14 | haines junction
# Processing Record 7 of Set 14 | qaqortoq
# Processing Record 8 of Set 14 | ritchie
# Processing Record 9 of Set 14 | kemlya
# Processing Record 10 of Set 14 | sembakung
# Processing Record 11 of Set 14 | nadapuram
# Processing Record 12 of Set 14 | maragogi
# Processing Record 13 of Set 14 | maniitsoq
# Processing Record 14 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 14 | rawson
# Processing Record 17 of Set 14 | nyalikungu
# Processing Record 18 of Set 14 | saint-augustin
# Processing Record 19 of Set 14 | shchuchye
# City not found. Skipping...
# Processing Record 20 of Set 14 | iquique
# Processing Record 21 of Set 14 | linqu
# Processing Record 22 of Set 14 | gold coast
# Processing Record 23 of Set 14 | griffith
# Processing Record 24 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | astipalaia
# City not found. Skipping...
# Processing Record 26 of Set 14 | san patricio
# Processing Record 27 of Set 14 | sur
# Processing Record 28 of Set 14 | lienz
# Processing Record 29 of Set 14 | luena
# Processing Record 30 of Set 14 | talcahuano
# Processing Record 31 of Set 14 | poronaysk
# Processing Record 32 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 33 of Set 14 | nizhniy baskunchak
# Processing Record 34 of Set 14 | moindou
# Processing Record 35 of Set 14 | zemlyansk
# Processing Record 36 of Set 14 | mayya
# Processing Record 37 of Set 14 | jishou
# Processing Record 38 of Set 14 | arman
# Processing Record 39 of Set 14 | muros
# Processing Record 40 of Set 14 | agutaya
# Processing Record 41 of Set 14 | puerto escondido
# Processing Record 42 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 14 | makakilo city
# Processing Record 44 of Set 14 | qunduz
# Processing Record 45 of Set 14 | high level
# Processing Record 46 of Set 14 | morelia
# Processing Record 47 of Set 14 | lisakovsk
# Processing Record 48 of Set 14 | caledon east
# Processing Record 49 of Set 14 | bata
# Processing Record 50 of Set 14 | marawi
# Processing Record 1 of Set 15 | xining
# Processing Record 2 of Set 15 | boende
# Processing Record 3 of Set 15 | anton lizardo
# Processing Record 4 of Set 15 | iquitos
# Processing Record 5 of Set 15 | storforshei
# Processing Record 6 of Set 15 | alakurtti
# Processing Record 7 of Set 15 | nishihara
# Processing Record 8 of Set 15 | najran
# Processing Record 9 of Set 15 | loyga
# Processing Record 10 of Set 15 | akureyri
# Processing Record 11 of Set 15 | santa maria
# Processing Record 12 of Set 15 | nigde
# Processing Record 13 of Set 15 | greensburg
# Processing Record 14 of Set 15 | cumberland
# Processing Record 15 of Set 15 | aste
# Processing Record 16 of Set 15 | north bend
# Processing Record 17 of Set 15 | tucupita
# Processing Record 18 of Set 15 | rivadavia
# Processing Record 19 of Set 15 | aden
# Processing Record 20 of Set 15 | santiago
# Processing Record 21 of Set 15 | nordfjordeid
# Processing Record 22 of Set 15 | brae
# Processing Record 23 of Set 15 | tena
# Processing Record 24 of Set 15 | mopti
# Processing Record 25 of Set 15 | kjopsvik
# Processing Record 26 of Set 15 | bathurst
# Processing Record 27 of Set 15 | golden
# Processing Record 28 of Set 15 | omboue
# Processing Record 29 of Set 15 | alghero
# Processing Record 30 of Set 15 | majene
# Processing Record 31 of Set 15 | mitu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Vendas Novas  38.68   -8.46     62.60        88          40       13.87
# 1          Arlit  18.74    7.39     76.28        23           0       13.06
# 2     Santa Cruz -17.80  -63.17    100.40        29           0       17.22
# 3      Montepuez -13.13   39.00     73.89        69          50        8.77
# 4  Cockburn Town  21.46  -71.14     78.80        78          90       11.41
# 5     Lubumbashi -11.66   27.48     69.15        31          16        3.87
# 6    Yellowknife  62.46 -114.35     12.99        85          90        5.82
# 7    Tuktoyaktuk  69.45 -133.04     26.60        79          75       21.92
# 8      Caravelas -17.71  -39.25     76.48        84           0        5.82
# 9      Grindavik  63.84  -22.43     41.00        75          75       23.04
#
#   Country                 Date
# 0      PT  2020-11-07 20:36:29
# 1      NE  2020-11-07 20:36:29
# 2      BO  2020-11-07 20:33:45
# 3      MZ  2020-11-07 20:33:51
# 4      TC  2020-11-07 20:35:10
# 5      CD  2020-11-07 20:36:29
# 6      CA  2020-11-07 20:36:45
# 7      CA  2020-11-07 20:37:19
# 8      BR  2020-11-07 20:37:19
# 9      IS  2020-11-07 20:37:19

# %%
# Create the output file (CSV).
output_data_file = "Weather_DatabaseR/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
